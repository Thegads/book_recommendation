# %%
import requests as rq
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import TimeoutException
import time

# %%
# queries = ['machine+learning','data+science']
queries = ['natural+langague+processing']
links = []
for query in queries:
    for i in range(1,2):
        driver = webdriver.Chrome('C:/Users/Gustavo/Desktop/curso_de_python/Scrapping/Sites/chromedriver')
        url = "https://www.amazon.com/s?k=%s&page=%s" % (query,i)
        driver.get(url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        link = [link.get('href') for link in soup.findAll('a',{'class':'a-link-normal a-text-normal'})]
        for j in range(len(link)):
            links.append(link[j])
        driver.close()
        time.sleep(2)

# %%
soup
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.20.6-2020-09-28" lang="en-us"><!-- sp:feature:head-start --><head><script async="" crossorigin="anonymous" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics.min.js"></script><script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31YXrY93hfL.js"></script><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(links)

# %%
df.to_excel('erros2.xlsx')

# %%
links = []
driver = webdriver.Chrome('C:/Users/Gustavo/Desktop/curso_de_python/Scrapping/Sites/chromedriver')
url = "https://www.amazon.com/s?k=natural+langague+processing&page=1"
driver.get(url)
soup = BeautifulSoup(driver.page_source)
link = [link.get('href') for link in soup.findAll('a',{'class':'a-link-normal a-text-normal'})]
for j in range(len(link)):
    links.append(link[j])
driver.close()

# %%
links
# Out:
# ['/Practical-Natural-Language-Processing-Pragmatic/dp/1492054054/ref=sr_1_1?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-1',
#  '/Practical-Hybrid-Natural-Language-Processing/dp/3030448290/ref=sr_1_2?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-2',
#  '/Natural-Language-Processing-Python-Analyzing/dp/0596516495/ref=sr_1_3?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-3',
#  '/Natural-Language-Processing-Action-Understanding/dp/1617294632/ref=sr_1_4?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-4',
#  '/Introduction-Language-Processing-Adaptive-Computation/dp/0262042843/ref=sr_1_5?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-5',
#  '/dp/B085C6LR8M?searchxofy=true&binding=kindle_edition&ref_=dbs_s_aps_series_rwt_tkin',
#  '/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_6?dchild=1&keywords=natural+language+processing&qid=1604932463&sr=8-6',
# ...

# %%
links = list(dict.fromkeys(links))
links
# Out:
# ['/Practical-Natural-Language-Processing-Pragmatic/dp/1492054054/ref=sr_1_1?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-1',
#  '/Practical-Hybrid-Natural-Language-Processing/dp/3030448290/ref=sr_1_2?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-2',
#  '/Natural-Language-Processing-Python-Analyzing/dp/0596516495/ref=sr_1_3?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-3',
#  '/Introduction-Language-Processing-Adaptive-Computation/dp/0262042843/ref=sr_1_4?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-4',
#  '/dp/B085C6LR8M?searchxofy=true&ref_=dbs_s_aps_series_rwt',
#  '/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_5?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-5',
#  '/Natural-Language-Processing-Action-Understanding/dp/1617294632/ref=sr_1_6?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-6',
# ...

# %%
print(len(links), len(mylist), len(mylist2))
# Out:
# 19 18 16

# %%
mylist = [x for x in mylist if not x.startswith('/dp/B0') and not x.startswith('https://')]

# %%
mylist
# Out:
# ['/Practical-Natural-Language-Processing-Pragmatic/dp/1492054054/ref=sr_1_1?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-1',
#  '/Practical-Hybrid-Natural-Language-Processing/dp/3030448290/ref=sr_1_2?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-2',
#  '/Natural-Language-Processing-Python-Analyzing/dp/0596516495/ref=sr_1_3?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-3',
#  '/Introduction-Language-Processing-Adaptive-Computation/dp/0262042843/ref=sr_1_4?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-4',
#  '/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_5?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-5',
#  '/Natural-Language-Processing-Action-Understanding/dp/1617294632/ref=sr_1_6?dchild=1&keywords=natural+language+processing&qid=1603840364&sr=8-6',
# ...
